# %%
getwd()
old_data <- read.csv("C:/Users/meizhi/Desktop/final/bat.csv", header = FALSE)
qtr <- as.numeric(as.character(old_data[2:53,1]))
acc <- as.numeric(as.character(old_data[2:53,2]))
fuel <- as.numeric(as.character(old_data[2:53,3]))

rate <- acc/fuel

data = data.frame(qtr=qtr, acc=acc, fuel=fuel, rate=rate)
head(data)
# Out:
# [1] "C:/Users/meizhi/Desktop"
#   qtr acc fuel   rate
# 1 1   192 32.592 5.891016
# 2 2   238 37.250 6.389262
# 3 3   232 40.032 5.795364
# 4 4   246 35.852 6.861542
# 5 5   185 38.226 4.839638
# 6 6   274 38.711 7.078091

# %%
install.packages('TTR')
# Out:
#   There is a binary version available but the source version is later:
#     binary source needs_compilation
# TTR 0.24.2 0.24.3              TRUE
#
#   Binaries will be installed
# package 'TTR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\meizhi\AppData\Local\Temp\RtmpcDCgWJ\downloaded_packages

# %%
install.packages('zoo')
# Out:
#   There is a binary version available but the source version is later:
#     binary source needs_compilation
# zoo  1.8-9 1.8-10              TRUE
#
#   Binaries will be installed
# package 'zoo' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\meizhi\AppData\Local\Temp\RtmpcDCgWJ\downloaded_packages

# %%
par(pin = c(3,2))
#par(mfrow=c(2,2))
plot(rate, type="o")
# Out:
# plot without title

# %%
par(pin = c(3,2))
dataTs <- ts(data, frequency=4, start=c(1972),end=c(1984))
rateTs <- ts(rate, frequency=4, start=c(1972),end=c(1984))
plot(rateTs)
# Out:
# plot without title

# %%
library(TTR)
par(mfrow = c(2,2))
ylim <- c(min(rateTs), max(rateTs))
rateSMA1<-SMA(rateTs,3)
rateSMA2<-SMA(rateTs,7)
rateSMA3<-SMA(rateTs,12)
plot(rateTs, main = "Raw time series",type="l")
plot(rateSMA1,main='SMA(k=3)',ylim=ylim,type="l")
plot(rateSMA2,main='SMA(k=7)',ylim=ylim,type="l")
plot(rateSMA3,main='SMA(k=12)',ylim=ylim,type="l")
# Out:
# Warning message:
# "package 'TTR' was built under R version 3.6.3"Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Plot with title "SMA(k=12)"

# %%
#plot(rateTs)
#对数变换
par(mfrow = c(2,2))
lrateTs <- log(rateTs)
#画出对数变换后的时间序列
plot(lrateTs, ylab="log(AirPassengers)")
#分解时间序列
fit <- stl(lrateTs, s.window="period")
#画出分解序列的结果
plot(fit)
fit$time.series
# Out:
# plot without title
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : 正式参数"cols"有多个与之相对应的实际参数
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_markdown.ts(obj)
# 9. repr_ts_generic(obj, repr_markdown.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
#         seasonal     trend    remainder
# 1972 Q1 -0.128137946 1.843971  0.057595209
# 1972 Q2  0.059198209 1.824492 -0.029071624
# 1972 Q3  0.078006578 1.807147 -0.128094861
# 1972 Q4 -0.009066711 1.792717  0.142281715
# 1973 Q1 -0.128137946 1.814407 -0.109428670
# 1973 Q2  0.059198209 1.780856  0.116950371
# 1973 Q3  0.078006578 1.732487  0.008575736
# 1973 Q4 -0.009066711 1.701953 -0.114442918
# 1974 Q1 -0.128137946 1.708113 -0.024858265
# 1974 Q2  0.059198209 1.763966  0.018243236
# 1974 Q3  0.078006578 1.815536  0.050134521
# 1974 Q4 -0.009066711 1.838047 -0.003770411
# 1975 Q1 -0.128137946 1.818152  0.023171938
# 1975 Q2  0.059198209 1.779878  0.045645181
# 1975 Q3  0.078006578 1.778488 -0.134557381
# 1975 Q4 -0.009066711 1.802273 -0.016875341
# 1976 Q1 -0.128137946 1.840328  0.123229887
# 1976 Q2  0.059198209 1.860743 -0.040837696
# 1976 Q3  0.078006578 1.836916  0.039272782
# 1976 Q4 -0.009066711 1.829526 -0.079289757
# 1977 Q1 -0.128137946 1.834649  0.028631665
# 1977 Q2  0.059198209 1.845536  0.015077799
# 1977 Q3  0.078006578 1.851162  0.009554450
# 1977 Q4 -0.009066711 1.847231 -0.034030183
# 1978 Q1 -0.128137946 1.833068  0.051607805
# 1978 Q2  0.059198209 1.824202 -0.023205801
# 1978 Q3  0.078006578 1.822328 -0.031913961
# 1978 Q4 -0.009066711 1.840693 -0.007280870
# 1979 Q1 -0.128137946 1.862941  0.014884513
# 1979 Q2  0.059198209 1.866079  0.068887891
# 1979 Q3  0.078006578 1.862481 -0.078620096
# 1979 Q4 -0.009066711 1.844172  0.037467455
# 1980 Q1 -0.128137946 1.836789  0.001120984
# 1980 Q2  0.059198209 1.835820 -0.019364369
# 1980 Q3  0.078006578 1.831631 -0.007958123
# 1980 Q4 -0.009066711 1.818902  0.052436441
# 1981 Q1 -0.128137946 1.810038 -0.024707181
# 1981 Q2  0.059198209 1.794057 -0.049385432
# 1981 Q3  0.078006578 1.758441  0.119278503
# 1981 Q4 -0.009066711 1.718930 -0.052455356
# 1982 Q1 -0.128137946 1.677028 -0.016822382
# 1982 Q2  0.059198209 1.669878 -0.082571416
# 1982 Q3  0.078006578 1.667504  0.114058313
# 1982 Q4 -0.009066711 1.664622 -0.015795655
# 1983 Q1 -0.128137946 1.659196 -0.058338108
# 1983 Q2  0.059198209 1.681991 -0.030984018
# 1983 Q3  0.078006578 1.716851  0.034941052
# 1983 Q4 -0.009066711 1.744562  0.088544766
# 1984 Q1 -0.128137946 1.771409 -0.075579820
# plot without title

# %%
trainData <- data.frame(data[1:30,4])
head(trainData)
train_set <- ts(trainData, frequency=4, start=c(1972),end=c(1984))
train_set
# Out:
#   data.1.30..4.
# 1 5.891016
# 2 6.389262
# 3 5.795364
# 4 6.861542
# 5 4.839638
# 6 7.078091
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : 正式参数"cols"有多个与之相对应的实际参数
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_markdown.ts(obj)
# 9. repr_ts_generic(obj, repr_markdown.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
#      Qtr1     Qtr2     Qtr3     Qtr4
# 1972 5.891016 6.389262 5.795364 6.861542
# 1973 4.839638 7.078091 6.166114 4.847406
# 1974 4.735640 6.305408 6.984388 6.204099
# 1975 5.546605 6.584517 5.595360 5.908138
# 1976 6.267766 6.547631 7.058241 5.704013
# 1977 5.669738 6.819678 6.949867 6.074709
# 1978 5.792347 6.424983 6.478059 6.198734
# 1979 5.752807 7.346064 5.891016 6.389262
# 1980 5.795364 6.861542 4.839638 7.078091
# 1981 6.166114 4.847406 4.735640 6.305408
# 1982 6.984388 6.204099 5.546605 6.584517
# 1983 5.595360 5.908138 6.267766 6.547631
# 1984 7.058241

# %%
testData <- data.frame(data[30:52,4])
head(testData)
test_set <- ts(testData, frequency=4, start=c(1972),end=c(1984))
test_set
# Out:
#   data.30.52..4.
# 1 7.346064
# 2 6.435741
# 3 6.505014
# 4 5.527700
# 5 6.525082
# 6 6.697134
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : 正式参数"cols"有多个与之相对应的实际参数
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_markdown.ts(obj)
# 9. repr_ts_generic(obj, repr_markdown.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
#      Qtr1     Qtr2     Qtr3     Qtr4
# 1972 7.346064 6.435741 6.505014 5.527700
# 1973 6.525082 6.697134 6.438344 5.244566
# 1974 6.073104 7.069048 5.245698 4.627736
# 1975 5.188810 6.420966 5.153932 4.361081
# 1976 5.530096 6.232634 6.196841 4.795563
# 1977 6.603097 5.585188 5.587127 7.346064
# 1978 6.435741 6.505014 5.527700 6.525082
# 1979 6.697134 6.438344 5.244566 6.073104
# 1980 7.069048 5.245698 4.627736 5.188810
# 1981 6.420966 5.153932 4.361081 5.530096
# 1982 6.232634 6.196841 4.795563 6.603097
# 1983 5.585188 5.587127 7.346064 6.435741
# 1984 6.505014

# %%
#取对数可以减少极值带来的影响，消除方差不齐。

par(mfrow = c(2,2))
train_setLog <- log(train_set)

HwModel<-HoltWinters(train_setLog)

HwModel

#用黑线画出原始数据的时间曲线图，用红线在上面画出预测值的时间曲线图：
plot(train_setLog)
plot(HwModel)
# Out:
# Holt-Winters exponential smoothing with trend and additive seasonal component.
#
# Call:
# HoltWinters(x = train_setLog)
#
# Smoothing parameters:
#  alpha: 0.01618769
#  beta : 0.3891143
#  gamma: 0.5130867
#
# Coefficients:
#            [,1]
# a  1.6927123940
# b  0.0002588038
# s1 0.0845141965
# s2 0.0577411647
# s3 0.1815087578
# s4 0.1792672685
# Plot with title "Holt-Winters filtering"

# %%
install.packages('forecast')
# Out:
#   There is a binary version available but the source version is later:
#          binary source needs_compilation
# forecast   8.14   8.16              TRUE
#
#   Binaries will be installed
# Warning message:
# "package 'forecast' is in use and will not be installed"

# %%
library(forecast)
par(mfrow = c(3,2))
predict <- forecast(HwModel)
plot(predict)

accuracy(predict)
# Out:
#              ME        RMSE      MAE        MPE       MAPE     MASE
# Training set 0.0221452 0.1274983 0.09447333 0.9288061 5.337807 0.8736101
#              ACF1
# Training set 0.007370375
# Plot with title "Forecasts from HoltWinters"

# %%
Box.test(predict$residuals,lag=20,type="Ljung-Box")
# Out:
# 	Box-Ljung test
#
# data:  predict$residuals
# X-squared = 13.199, df = 20, p-value = 0.8687

# %%
plot.ts(predict$residuals) # make a time plot
# Out:
# plot without title
